# %%
import pandas as pd
pd.set_option('display.max_rows',1000)

# %%
path = 'C:/Users/Sarv/Downloads/test/gohar/'

dir_file_path1 = 'C:/Users/Sarv/Downloads/test/gohar/13990431.xlsx'
dir_file_path2 = 'C:/Users/Sarv/Downloads/test/gohar/13990531.xlsx'
dir_file_path3 = 'C:/Users/Sarv/Downloads/test/gohar/13990631.xlsx'
dir_file_path4 = 'C:/Users/Sarv/Downloads/test/gohar/13990730.xlsx'
dir_file_path5 = 'C:/Users/Sarv/Downloads/test/gohar/13990830.xlsx'
dir_file_path6 = 'C:/Users/Sarv/Downloads/test/gohar/13990930.xlsx'
dir_file_path7 = 'C:/Users/Sarv/Downloads/test/gohar/13991030.xlsx'
dir_file_path8 = 'C:/Users/Sarv/Downloads/test/gohar/13991130.xlsx'
dir_file_path9 = 'C:/Users/Sarv/Downloads/test/gohar/13991230.xlsx'
dir_file_path10 = 'C:/Users/Sarv/Downloads/test/gohar/14000131.xlsx'
dir_file_path11 = 'C:/Users/Sarv/Downloads/test/gohar/14000231.xlsx'
dir_file_path12 = 'C:/Users/Sarv/Downloads/test/gohar/14000331.xlsx'
dir_file_path13 = 'C:/Users/Sarv/Downloads/test/gohar/14000431.xlsx'
dir_file_path14 = 'C:/Users/Sarv/Downloads/test/gohar/14000531.xlsx'
dir_file_path15 = 'C:/Users/Sarv/Downloads/test/gohar/14000631.xlsx'
dir_file_path16 = 'C:/Users/Sarv/Downloads/test/gohar/14000730.xlsx'
dir_file_path17 = 'C:/Users/Sarv/Downloads/test/gohar/14000830.xlsx'
dir_file_path18 = 'C:/Users/Sarv/Downloads/test/gohar/14000930.xlsx'
dir_file_path19 = 'C:/Users/Sarv/Downloads/test/gohar/14001030.xlsx'

# %%
#extract_all_sheets

file_name = dir_file_path19.split('/')[6].split('.')[0]
for i in range(0,14):
    df = pd.read_excel(dir_file_path19,sheet_name=i)
    sheet_name = file_name+f'_{i}'
    df.to_excel(f'C:/Users/Sarv/Downloads/test/gohar/{sheet_name}.xlsx', index=False)

# %%
#Sheet_01

df_raw = pd.read_excel(path + '14001030_1.xlsx')
df = df_raw.iloc[14:,:].dropna(how='all',axis=1).iloc[:,:12]
df.columns = ['stock_name','vol_last','cost_last','value_last'
             ,'vol_buy','cost_buy','vol_sell','value_sell'
             ,'vol_current','unit_price','cost_current', 'value_current']
df
# Out:
#                         stock_name   vol_last      cost_last     value_last  \
# 14               ح . دارویی‌ رازک‌          0              0              0
# 15                   پتروشیمی غدیر      85000     9745404249     7536042157
# 16               پارس فولاد سبزوار     421930    15654600118    14449002343
# 17                       البرزدارو     158000     2466061173     1839171429
# 18   صنایع شیمیایی کیمیاگران امروز     607472    12342878765    17912830114
# 19          دلیجان طلایی شکوه پارس    8425437    27001619902    29690458528
# 20  توسعه سامانه ی نرم افزاری نگین     325804     2488141702     6053369428
# 21              ریل پرداز نو آفرین    1394767     4652979484     6890915055
# 22                  آریان کیمیا تک     103000     2371198430     2589163182
# 23                     سپید ماکیان    1675210    84535863223    98057017910
# 24              زغال سنگ پروده طبس     560000    20178305173    16597613088
# ...

# %%
#Sheet_02

df_raw2 = pd.read_excel(path + '14001030_2.xlsx')
df2 = df_raw2.iloc[10:,:].dropna(how='all',axis=1).drop(columns=['Unnamed: 12','Unnamed: 22'])
df2.columns = ['option_name', 'vol_last', 'strik_price_last', 'expirate_date_last'
              ,'vol_current', 'strike_price_current', 'expiration_date_current']
df2
# Out:
#                        option_name  vol_last strik_price_last  \
# 10    اختیارف ت سپید22620-01/04/22    155210            22620
# 11    اختیارف ت کویر-8282-01/10/05  22444286             8282
# 12  اختیارف ت کیمیا-28750-01/06/16    103000            28750
# 13   اختیارف.ت. حآفرین-3996-010621   1394767             3996
# 14                          جمع کل  24097263              NaN
#
#    expirate_date_last vol_current strike_price_current expiration_date_current
# 10         1401/04/22      155210                22620              1401/04/22
# 11         1401/10/05    22444286                 8282              1401/10/05
# 12         1401/06/16      103000                28750              1401/06/16
# 13         1401/06/21     1394767                 3996              1401/06/21
# 14                NaN    24097263                  NaN                     NaN

# %%
#Sheet_03

df_raw3 = pd.read_excel(path + '14001030_3.xlsx')
df3 = df_raw3.iloc[12:,:].dropna(how='all', axis=1).iloc[:,:17]
df3.columns = ['bond_name', 'registered', 'market'
              ,'issue_date', 'due_date','nominal_rate'
              ,'vol_last', 'cost_last', 'value_last'
              ,'vol_buy', 'cost_buy', 'vol_sell', 'value_sell'
              ,'vol_current', 'unit_price', 'cost_current', 'value_current']
df3
# Out:
#                          bond_name registered      market  issue_date  \
# 12      مرابحه کرمان موتور14030915        بلی     فرابورس  1400/09/15
# 13     مرابحه عام دولت89-ش.خ041120        بلی        بورس  1400/05/20
# 14    ص مرابحه خودرو401- 3ماهه 18%        بلی        بورس  1400/01/14
# 15   صکوک مرابحه بهمن404-3ماهه 18%        بلی        بورس  1400/04/13
# 16      مرابحه کرمان موتور14030614        بلی     فرابورس  1400/06/14
# 17     مرابحه عام دولت75-ش.خ040226        بلی        بورس  1399/11/26
# 18        مرابحه بهمن دیزل14040331        بلی     فرابورس  1400/03/31
# 19     %مشاركت ش اصفهان203-3ماهه18        بلی        بورس  1398/03/30
# 20     سلف موازی استاندارد سنفت101        بلی  بورس انرژی  1399/07/22
# 21    صکوک اجاره فارس307- 3ماهه18%        بلی        بورس  1399/07/13
# 22     صکوک اجاره پارسیان-6ماهه16%        بلی        بورس  1399/06/10
# 23    اجاره اعتماد مبین تمدن010710        بلی     فرابورس  1397/07/10
# ...

# %%
#Sheet_05

df_raw5 = pd.read_excel(path + '14001030_5.xlsx')
df5 = df_raw5.iloc[11:,:].dropna(how='all', axis=1).iloc[:,:9]
df5.columns = ['deposit_name', 'deposit_num', 'deposit_type', 'opening_date', 'deposit_rate'
              ,'bal_last', 'credited', 'debited', 'bal_current']
df5
# Out:
#                                          deposit_name       deposit_num  \
# 11      سپرده بلند مدت-3089012115919731-بانک پاسارگاد  3089012115919731
# 12    سپرده بلند مدت-173352256498251-بانک توسعه تعاون   173352256498251
# 13   سپرده کوتاه مدت-173331156498251-بانک توسعه تعاون   173331156498251
# 14           سپرده بلند مدت-204239887708881-بانک سینا   204239887708881
# 15          سپرده کوتاه مدت-204814887708881-بانک سینا   204814887708881
# 16  سپرده کوتاه مدت-0200051459007-بانک توسعه صادرا...     0200051459007
# 17  سپرده کوتاه مدت-308.8100.11591973.1-بانک پاسارگاد  3088100115919731
# 18                   كوتاه مدت-47001045910606-پارسيان    47001045910606
# 19             سپرده کوتاه مدت-952456936-بانک کشاورزی         952456936
# 20                          کوتاه مدت-104456073-تجارت         104456073
# 21                         کوتاه مدت-700824359981-شهر      700824359981
# 22                                جاری-4905263074-ملت        4905263074
# ...

# %%
#Sheet_06

df_raw6 = pd.read_excel(path + '14001030_6.xlsx')
df6 = df_raw6.iloc[9:,:].dropna(how='all', axis=1).iloc[:,:3]
df6.columns = ['investment_income', 'page', 'income']
df6
# Out:
#                                     investment_income  page         income
# 9   درآمد حاصل از سرمایه گذاری در سهام و حق تقدم سهام  ‫1-2  -139626774102
# 10  ‫درآمد حاصل از سرمایه گذاری در اوراق بهادار با...  ‫2-2   112005472664
# 11  ‫درآمد حاصل از سرمایه گذاری در سپرده بانکی و گ...  ‫3-2    35193905505
# 12                                      ‫سایر درآمدها  ‫4-2      199574695
# 13                                             جمع کل   NaN     7772178762

# %%
#Sheet_07

df_raw7 = pd.read_excel(path + '14001030_7.xlsx')
df7 = df_raw7.iloc[10:,].dropna(how='all', axis=1)
df7.columns = ['stock_name', 'agm_date', 'vol_agm', 'per_profit_agm', 'total_income_added'
              ,'discount_cost_added', 'net_income_added', 'total_income_current'
              ,'discount_cost_current', 'net_income_current']
df7
# Out:
#                         stock_name    agm_date   vol_agm per_profit_agm  \
# 10                     سپید ماکیان  1400/04/27    155210           3000
# 11                       بیمه معلم  1400/04/20   2383134            300
# 12                 لیزینگ کارآفرین  1400/04/09    331840            165
# 13  تولید و توسعه سرب روی ایرانیان  1400/04/06     31396            110
# 14     سرمایه گذاری نیروگاهی ایران  1400/06/06   3300000            227
# 15     فرآوری معدنی اپال کانی پارس  1400/02/22  10027164            630
# 16              کارخانجات‌داروپخش‌  1400/03/26   2630000           1781
# 17                        بیمه  دی  1400/04/19    590000           4140
# 18                   دارویی‌ رازک‌  1400/03/04    878000           2980
# 19                          افرانت  1400/03/12     50000            700
# 20     تولیدی فولاد سپید فراب کویر  1400/04/29   9952442            151
# 21        گروه اقتصادي كرمان خودرو  1400/05/04   3940000             20
# ...

# %%
#Sheet_08

df_raw8 = pd.read_excel(path + '14001030_8.xlsx')
df8 = df_raw8.iloc[10:,:].dropna(how='all', axis=1)
df8.columns = ['deposit_name', 'payment_date', 'due_date', 'rate', 'interest_added'
                  ,'discount_cost_added', 'net_income_added', 'interest_current'
                  ,'discount_cost_current', 'net_income_current']
df8
# Out:
#                                          deposit_name payment_date  \
# 10      سپرده بلند مدت-3089012115919731-بانک پاسارگاد   1401/07/22
# 11    سپرده بلند مدت-173352256498251-بانک توسعه تعاون   1401/03/22
# 12   سپرده کوتاه مدت-173331156498251-بانک توسعه تعاون   1401/03/20
# 13           سپرده بلند مدت-204239887708881-بانک سینا   1401/03/18
# 14          سپرده کوتاه مدت-204814887708881-بانک سینا   1401/03/18
# 15  سپرده کوتاه مدت-0200051459007-بانک توسعه صادرا...   1401/02/21
# 16                   كوتاه مدت-47001045910606-پارسيان   1401/02/22
# 17             سپرده کوتاه مدت-952456936-بانک کشاورزی   1401/02/22
# 18                          کوتاه مدت-104456073-تجارت   1401/02/22
# 19                         کوتاه مدت-700824359981-شهر   1401/02/22
# 20                           کوتاه مدت-4903155270-ملت   1401/02/22
# 21                         کوتاه مدت-700792247960-شهر   1401/02/22
# 22                         مرابحه کرمان موتور14030915   1400/09/14
# ...

# %%
#Sheet_09

df_raw9 = pd.read_excel(path + '14001030_9.xlsx')
df9 = df_raw9.iloc[10:,:].dropna(how='all', axis=1)
df9.columns = ['stock_name', 'vol_added', 'sale_value_added', 'book_value_added'
              ,'sale_profit_added', 'vol_current', 'sale_value_current', 'book_value_current'
              ,'sale_profit_current']
df9
# Out:
#                                            stock_name vol_added  \
# 10                         مرابحه کرمان موتور14030915      1000
# 11                             دلیجان طلایی شکوه پارس         0
# 12                     توسعه سامانه ی نرم افزاری نگین    325804
# 13                                 ریل پرداز نو آفرین         0
# 14                                     آریان کیمیا تک         0
# 15                     س. و خدمات مدیریت صند. ب کشوری         0
# 16                             سرمایه گذاری هامون صبا         0
# 17                              ح . داروسازی‌ فارابی‌         0
# 18                                        سپید ماکیان         0
# 19                                        نفت ایرانول         0
# 20                                           لامیران‌         0
# 21                        مرابحه عام دولت75-ش.خ040226      1000
# 22                                 محصولات کاغذی لطیف         0
# 23                     گ.مدیریت ارزش سرمایه ص ب کشوری         0
# ...

# %%
#Sheet_10

df_raw10 = pd.read_excel(path + '14001030_10.xlsx')
df10 = df_raw10.iloc[10:,:].dropna(how='all', axis=1).iloc[:,:9]
df10.columns = ['stock_name', 'vol_added', 'sale_value_added', 'book_value_added'
              ,'capital_gain_added', 'vol_current', 'sale_value_current', 'book_value_current'
              ,'capital_gain_current']
df10
# Out:
#                                            stock_name  vol_added  \
# 10                                  ح . دارویی‌ رازک‌     854630
# 11                         مرابحه کرمان موتور14030915      24000
# 12                        مرابحه عام دولت89-ش.خ041120       1000
# 13                       ص مرابحه خودرو401- 3ماهه 18%       9000
# 14                                      پتروشیمی غدیر      85000
# 15                                  پارس فولاد سبزوار     421930
# 16                                          البرزدارو     158000
# 17                      صنایع شیمیایی کیمیاگران امروز     607472
# 18                             دلیجان طلایی شکوه پارس    8425437
# 19                     توسعه سامانه ی نرم افزاری نگین     325804
# 20                                 ریل پرداز نو آفرین    1394767
# 21                                     آریان کیمیا تک     103000
# 22                      صکوک مرابحه بهمن404-3ماهه 18%       3000
# ...

# %%
#Sheet_11

df_raw11 = pd.read_excel(path + '14001030_11.xlsx')
df11 = df_raw11.iloc[10:,:].dropna(how='all', axis=1).drop(columns=['Unnamed: 15','Unnamed: 25'])
df11.columns = ['stock_name', 'dividend_added', 'capital_gain_added', 'sale_income_added'
                ,'total_income_added', 'dividend_current', 'capital_gain_current', 'sale_income_current'
                ,'total_income_current']
df11
# Out:
#                         stock_name dividend_added capital_gain_added  \
# 10                     سپید ماکیان              0        -2115020597
# 11                       بیمه معلم              0         -554253391
# 12                 لیزینگ کارآفرین              0                  0
# 13  تولید و توسعه سرب روی ایرانیان              0                  0
# 14     سرمایه گذاری نیروگاهی ایران              0                  0
# 15     فرآوری معدنی اپال کانی پارس              0         3784691436
# 16              کارخانجات‌داروپخش‌       81954764        -1972397509
# 17                        بیمه  دی       49113242                  0
# 18                   دارویی‌ رازک‌       35357297         7138932364
# 19                          افرانت              0                  0
# 20     تولیدی فولاد سپید فراب کویر              0         1692960140
# 21        گروه اقتصادي كرمان خودرو              0          767645172
# 22                  پديده شيمي قرن              0         7356197836
# ...

# %%
#Sheet_12

df_raw12 = pd.read_excel(path + '14001030_12.xlsx')
df12 = df_raw12.iloc[10:,:].dropna(how='all', axis=1).iloc[:,0:12].drop(columns=['Unnamed: 15','Unnamed: 25'])
df12.columns = ['bond_name', 'interest_added', 'capital_gain_added',  'sale_income_added'
               ,'total_income_added', 'interest_current', 'capital_gain_current', 'sale_income_current'
               , 'total_income_current']
# 'Underwriting_income_added',
# 'Underwriting_income_current',
df12
# Out:
#                          bond_name interest_added capital_gain_added  \
# 10      مرابحه کرمان موتور14030915      347015822          144155150
# 11     مرابحه عام دولت89-ش.خ041120       14589944           -3677533
# 12    ص مرابحه خودرو401- 3ماهه 18%       53439137          237625626
# 13   صکوک مرابحه بهمن404-3ماهه 18%       37634097           12873471
# 14      مرابحه کرمان موتور14030614      457816422                  0
# 15     مرابحه عام دولت75-ش.خ040226      138921207          193487442
# 16        مرابحه بهمن دیزل14040331      359138204          238370326
# 17     %مشاركت ش اصفهان203-3ماهه18        4352106           14663781
# 18    صکوک اجاره فارس307- 3ماهه18%      324178927           50950725
# 19     صکوک اجاره پارسیان-6ماهه16%      204108938          300865458
# 20    اجاره اعتماد مبین تمدن011019              0                  0
# 21    اجاره اعتماد مبین تمدن010710      354841519                  0
# 22   مرابحه عام دولت2-ش.خ تمدن0212      135509002                  0
# ...

# %%
#Sheet_13

df_raw13 = pd.read_excel(path + '14001030_13.xlsx')
df13 = df_raw13.iloc[10:,:].dropna(how='all', axis=1).drop(columns=['Unnamed: 9', 'Unnamed: 15'])
df13.columns = ['deposit_name', 'account_num', 'interest_added', 'interest_current']

df13
# Out:
#                                          deposit_name       account_num  \
# 10      سپرده بلند مدت-3089012115919731-بانک پاسارگاد  3089012115919730
# 11    سپرده بلند مدت-173352256498251-بانک توسعه تعاون   173352256498251
# 12   سپرده کوتاه مدت-173331156498251-بانک توسعه تعاون   173331156498251
# 13           سپرده بلند مدت-204239887708881-بانک سینا   204239887708881
# 14          سپرده کوتاه مدت-204814887708881-بانک سینا   204814887708881
# 15  سپرده کوتاه مدت-0200051459007-بانک توسعه صادرا...      200051459007
# 16                   كوتاه مدت-47001045910606-پارسيان    47001045910606
# 17             سپرده کوتاه مدت-952456936-بانک کشاورزی         952456936
# 18                          کوتاه مدت-104456073-تجارت         104456073
# 19                         کوتاه مدت-700824359981-شهر      700824359981
# 20                           کوتاه مدت-4903155270-ملت        4903155270
# 21                         کوتاه مدت-700792247960-شهر      700792247960
# ...

# %%
#Sheet_14

df_raw14 = pd.read_excel(path + '14001030_14.xlsx')
df14 = df_raw14.iloc[10:,:].dropna(how='all',axis=1)
df14.columns = ['other_income', 'value_added', 'value_current']
df14
# Out:
#                   other_income value_added value_current
# 10  کارگزاری بانک توسعه صادرات      -37026     199574694
# 11                      جمع کل      -37026     199574695

# %%
df.to_csv(path + '14001030_1.csv', encoding = 'utf_8_sig', index=False)
df2.to_csv(path + '14001030_2.csv', encoding = 'utf_8_sig', index=False)
df3.to_csv(path + '14001030_3.csv', encoding = 'utf_8_sig', index=False)
df5.to_csv(path + '14001030_5.csv', encoding = 'utf_8_sig', index=False)
df6.to_csv(path + '14001030_6.csv', encoding = 'utf_8_sig', index=False)
df7.to_csv(path + '14001030_7.csv', encoding='utf_8_sig', index=False)
df8.to_csv(path + '14001030_8.csv', encoding='utf_8_sig', index=False)
df9.to_csv(path + '14001030_9.csv', encoding='utf_8_sig', index=False)
df10.to_csv(path + '14001030_10.csv', encoding='utf_8_sig', index=False)
df11.to_csv(path + '14001030_11.csv', encoding='utf_8_sig', index=False)
df12.to_csv(path + '14001030_12.csv', encoding='utf_8_sig', index=False)
df13.to_csv(path + '14001030_13.csv', encoding='utf_8_sig', index=False)
df14.to_csv(path + '14001030_14.csv', encoding='utf_8_sig', index=False)
