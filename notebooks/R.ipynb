# %%
install.packages('googledrive')
install.packages('httpuv')
library ('googledrive')
library ('httpuv')

# %%
if (file.exists("/usr/local/lib/python3.7/dist-packages/google/colab/_ipython.py")) { #may update python version  
                                       #occasionally
  install.packages("R.utils")
  library("R.utils")
  library("httr")
  my_check <- function() {return(TRUE)}
  reassignInPackage("is_interactive", pkgName = "httr", my_check) 
  options(rlang_interactive=TRUE)
}

# %%
drive_auth(use_oob=TRUE, cache=FALSE)
# Out:
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/auth?client_id=603366585132-dpeg5tt0et3go5of2374d83ifevk5086.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code
# Enter authorization code: 4/1AX4XfWg7DGk8OG8vX6O_TxGcKwa3fYKAYxqTIOub4B1rmhngMtpaACQFLLk

# %%
library ('tidyverse')
library ('readxl')

# %%
data <- read_excel('/content/gdrive/MyDrive/Library/Model_1.xlsx')
# Out:
# Error: `path` does not exist: ‘/content/gdrive/MyDrive/Library/Model_1.xlsx’
# Traceback:
#
# 1. read_excel("/content/gdrive/MyDrive/Library/Model_1.xlsx")
# 2. check_file(path)
# 3. stop("`path` does not exist: ", sQuote(path), call. = FALSE)

# %%
install.packages('VIM')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library ('VIM')

# %%
library ('tidyverse')
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data
